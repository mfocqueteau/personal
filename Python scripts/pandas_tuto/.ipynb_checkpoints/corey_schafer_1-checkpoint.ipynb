# %%
import pandas as pd

# %%
pd.set_option('display.max_columns', 25)

# %%
df = pd.read_csv('ds2_weapons_normal.csv', index_col='Weapon')
df.head(10)
# Out:
#                               STR   DEX  INT   FTH  Units    Phy  Magic  Fire  \
# Weapon
# Bound Hand Axe               15.0   7.0  NaN   NaN    3.5  180.0    NaN   NaN
# Dragonslayer's Crescent Axe  18.0  12.0  NaN   NaN    7.0  200.0    NaN   NaN
# Infantry Axe                  9.0   1.0  NaN   NaN    3.5  200.0    NaN   NaN
# Hand Axe                      9.0   3.0  NaN   NaN    2.0  270.0    NaN   NaN
# Battle Axe                   15.0   5.0  NaN   NaN    4.0  280.0    NaN   NaN
# Butcher's Knife              25.0   8.0  NaN   NaN   16.0  280.0    NaN   NaN
# Bandit Axe                   18.0   5.0  NaN   NaN    5.0  310.0    NaN   NaN
# Gyrm Axe                     28.0   6.0  NaN   NaN   18.0  380.0    NaN   NaN
# Bow of Want                   9.0  20.0  NaN  18.0    2.0  100.0    NaN   NaN
# Short Bow                     7.0  12.0  NaN   NaN    1.0  130.0    NaN   NaN
#
#                              Light  Dark  Bleed Poison  S   Dx    I    F    L  \
# Weapon
# Bound Hand Axe                 NaN   NaN  100.0    NaN  A  NaN  NaN  NaN  NaN
# Dragonslayer's Crescent Axe   60.0   NaN    NaN    NaN  C    E  NaN  NaN    C
# Infantry Axe                   NaN   NaN    NaN    NaN  B    D  NaN  NaN  NaN
# Hand Axe                       NaN   NaN    NaN    NaN  B  NaN  NaN  NaN  NaN
# Battle Axe                     NaN   NaN    NaN    NaN  B    D  NaN  NaN  NaN
# Butcher's Knife                NaN   NaN    NaN    NaN  A  NaN  NaN  NaN  NaN
# Bandit Axe                     NaN   NaN    NaN    NaN  B  NaN  NaN  NaN  NaN
# Gyrm Axe                       NaN   NaN    NaN    NaN  A    E  NaN  NaN  NaN
# Bow of Want                  130.0   NaN    NaN    NaN  C    A  NaN  NaN    C
# Short Bow                      NaN   NaN    NaN    NaN  D    A  NaN  NaN  NaN
#
#                               Dk Weapon Type        Damage Type  Poise Damage  \
# Weapon
# Bound Hand Axe               NaN         Axe              Slash            25
# Dragonslayer's Crescent Axe  NaN         Axe              Slash            30
# Infantry Axe                 NaN         Axe              Slash            25
# Hand Axe                     NaN         Axe              Slash            25
# Battle Axe                   NaN         Axe              Slash            30
# Butcher's Knife              NaN         Axe              Slash            40
# Bandit Axe                   NaN         Axe              Slash            30
# Gyrm Axe                     NaN         Axe              Slash            30
# Bow of Want                  NaN         Bow  Projectile/Strike             5
# Short Bow                    NaN         Bow  Projectile/Strike             5
#
#                              Counter  Durability  \
# Weapon
# Bound Hand Axe                   110          60
# Dragonslayer's Crescent Axe      130          60
# Infantry Axe                     110          50
# Hand Axe                         110          50
# Battle Axe                       120          60
# Butcher's Knife                  100          40
# Bandit Axe                       120          50
# Gyrm Axe                         110         120
# Bow of Want                      100          70
# Short Bow                        100          60
#
#                                                                          Notes
# Weapon
# Bound Hand Axe                                                             NaN
# Dragonslayer's Crescent Axe        Counter damage increased (Calibration 1.15)
# Infantry Axe                                     increased poise damage (1.15)
# Hand Axe                                                                   NaN
# Battle Axe                                                                 NaN
# Butcher's Knife              Increased poise damage, HP regain. (Calibratio...
# Bandit Axe                                                                 NaN
# Gyrm Axe                               Durability Increased (Calibration 1.15)
# Bow of Want                                                                NaN
# Short Bow                                                                  NaN

# %%
df.shape
# Out:
# (249, 24)

# %%
TIERS = ('S', 'A', 'B', 'C', 'D', 'E')
df['Dx'].value_counts()
# Out:
# A    40
# C    37
# D    29
# E    25
# B    21
# S    17
# Name: Dx, dtype: int64

# %%
df.columns
# Out:
# Index(['STR', 'DEX', 'INT', 'FTH', 'Units', 'Phy', 'Magic', 'Fire', 'Light',
#        'Dark', 'Bleed', 'Poison', 'S', 'Dx', 'I', 'F', 'L', 'Dk',
#        'Weapon Type', 'Damage Type', 'Poise Damage', 'Counter', 'Durability',
#        'Notes'],
#       dtype='object')

# %%
df[['STR', 'Dark']].head()
# Out:
#                               STR  Dark
# Weapon
# Bound Hand Axe               15.0   NaN
# Dragonslayer's Crescent Axe  18.0   NaN
# Infantry Axe                  9.0   NaN
# Hand Axe                      9.0   NaN
# Battle Axe                   15.0   NaN

# %%
# print(df.iloc[[0, 2], [0, 6]])
# print(df.loc[['row1', 'row2'], ['col1', 'col2']])
print(df.loc[['Claws', 'Heide Knight Sword'], 'Phy':'Dk'])
# Out:
#                       Phy  Magic  Fire  Light  Dark  Bleed Poison  S Dx    I  \
# Weapon
# Claws               155.0    NaN   NaN    NaN   NaN  120.0    NaN  E  A  NaN
# Heide Knight Sword  150.0    NaN   NaN   90.0   NaN    NaN    NaN  C  C  NaN
#
#                       F    L   Dk
# Weapon
# Claws               NaN  NaN  NaN
# Heide Knight Sword  NaN    C  NaN

# %%
# Obtener sólo las armas que escalan con S en STR o DEX
sdx_filter = (df['S'] == 'S') | (df['Dx'] == 'S')

# %%
# df[sdx_filter]

# %%
# Puede funcionar igual que el anterior, pero además podemos elegir columna específica.
df.loc[sdx_filter, ['Phy', 'S', 'Dx']]
# Out:
#                                   Phy    S   Dx
# Weapon
# Hunter's Blackbow               155.0    E    S
# Curved Dragon Greatsword        400.0    B    S
# Curved Nil Greatsword           290.0    S    B
# Monastery Scimitar              190.0    E    S
# Eleum Loyce                     165.0    E    S
# Umbral Dagger                    70.0  NaN    S
# Bone Fist                        20.0    S    A
# Twin-headed Greatbow            260.0    S  NaN
# Large Club                      360.0    S  NaN
# Drakeblood Greatsword           232.0    E    S
# Old Mirrah Greatsword           220.0    C    S
# Flamberge                       250.0    D    S
# Loyce Greatsword                230.0    E    S
# Club                            210.0    S  NaN
# Blacksteel Katana               190.0  NaN    S
# Chaos Blade                     265.0  NaN    S
# Bewitched Alonne Sword          180.0  NaN    S
# Partizan                        230.0    E    S
# Puzzling Stone Sword            145.0    E    S
# Fume Sword                      140.0  NaN    S
# Ricard's Rapier                 160.0  NaN    S
# Spider's Silk                   195.0  NaN    S
# Drakekeeper's Ultra Greatsword  330.0    S    D
# King's Ultra Greatsword         450.0    S    E
# Fume Ultra Greatsword           430.0    S    D
